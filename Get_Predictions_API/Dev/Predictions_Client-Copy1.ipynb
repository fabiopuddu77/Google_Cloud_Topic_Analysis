# %% [markdown]
# ### Get Predictions: Python Client

# %%
from main import main
from google.cloud import aiplatform as aip
from tabulate import tabulate

# %%
if __name__ == "__main__":
    
    newobs, instances, NOTEBOOK = main()
    print("newobs-----------------------------", newobs)
    print("instances-----------------------------",instances)
    aip.Endpoint.list(filter=f'labels.notebook={NOTEBOOK}')
    endpoint = aip.Endpoint.list(filter=f'labels.notebook={NOTEBOOK}')[0]
    print(f"ENDPOINTS: \n {endpoint.display_name}")
    prediction = endpoint.predict(instances = instances) # or instances = newobs
    
    dictionary=prediction.predictions[2]
    # Convert the dictionary into a list of tuples
    table_data = list(zip(dictionary['classes'], dictionary['scores']))

    # Print the table
    print("PREDICTIONS \n")
    print(tabulate(table_data, headers=['Class', 'Score'], tablefmt='grid'))
    #print(f"PREDICTIONS: \n {prediction.predictions[0]}")
# Out:
# INFO: Check if the file in exists in gcs output_processing.parquet
#
# INFO: output_processing.parquet  already exists in GCS. Skipping process.
#
# [nltk_data] Downloading package punkt to /home/jupyter/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/jupyter/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/jupyter/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# INFO: Check if the file in exists in gcs output_tokenized.parquet
#
# INFO: output_tokenized.parquet  already exists in GCS. Skipping process.
#
# INFO: Check if the file in exists in gcs output_sentiment.parquet
#
# INFO: File already exists in GCS. Skipping process.
#
# INFO: Check if the file in exists in gcs output_moderate.parquet
#
# INFO: File already exists in GCS. Skipping process.
#
# INFO: Check if the file in exists in gcs output_entities.parquet
# Check if the file in exists in gcs
# output_processing.parquet already exists in GCS. Skipping process.
# Data Preprocessing completed. Processed data saved at: output_processing.parquet
# Check if the file in exists in gcs
# output_tokenized.parquet already exists in GCS. Skipping process.
# Tokenization completed. Tokenized data saved at: output_tokenized.parquet
# Check if the file in exists in gcs
# File already exists in GCS. Skipping process.
# Sentiment Analysis completed. Sentiment data saved at: output_sentiment.parquet
# Check if the file in exists in gcs
# File already exists in GCS. Skipping process.
# Text Moderation completed. Moderated data saved at: output_moderate.parquet
# Check if the file in exists in gcs
# INFO: File already exists in GCS. Skipping process.
#
# INFO: Start loading DataFrame from output_entities.parquet
#
# INFO: Loaded DataFrame from output_entities.parquet
# File already exists in GCS. Skipping process.
# Entity Analysis completed. Entity data saved at: output_entities.parquet
# Start loading DataFrame from output_entities.parquet
# Loaded DataFrame from output_entities.parquet
# Loaded 20 rows into BigQuery table: gcp-ccai-auto-ml-contactcenter.datasetnlp.testdatabq
# BigQuery Upload completed. Status: testdatabq
# Create Dataframe prediction
# Adapt the variables to the autoML
# Create instances
# newobs----------------------------- [{'title': '"Dovevo andare alle giostre ma sono finito in orfanotrofio. Ho vissuto l\'inferno": la commovente confessione di Teo Mammucari a Ballando - Il Fatto Quotidiano', 'relevance': '1', 'authors': 'F. Q.', 'sourceTitle': 'Il Fatto Quotidiano', 'importanceRank': '191788', 'alexaGlobalRank': '3336', 'month': '12', 'shares_scaled': -0.25316455696202533, 'body_pre': "Teo Mammucari raccontato complicato passato riuscito perdonare madre nonostante dolore causato L'ultima puntata Ballando Stelle riuscita far emergere lato Teo Mammucari raramente visto televisione . L'attore raccontato complicato passato vissuto quasi interamente orfanotrofio . promessa andare assieme giostre , madre Mammucari l'ha invece lasciato suore : `` vissuto l'inferno , pensare solo bambino '' , spiegato l'attore , poi riuscito scappare collegio età adolescenziale , giorno compleanno . Grazie percorso psicoterapia , Teo riuscito 'convivere ' traumatico passato perdonando , dopo anni , l'azione madre . Prima esibirsi note de Vita adesso ( Claudio Baglioni ) , maestra Anastasia Kuzmina chiesto conoscenza motivo spinto mamma affidarlo orfanotrofio : `` madre difficoltà , sbagliato dirmelo resa conto . imparato perdonare , capire . cosa vedo tragedia , cosa fa godere ogni giorno vita , dopo aver vissuto l'inferno . bambino , mancava l'energia dell'amore . Quando poi fatto aiutare capito '' , detto Mammucari , risposta . `` chiesto parlare parte vita 5 anni fa , riuscito finire prima frase senza piangere '' , aggiunto l'attore inoltre specificato poteva tornare casa solamente durante festività Natale Pasqua . `` momento brutto stato quando entrato : c'era corridoio me , ogni volta passavo , tornare cella . diciotto anni , giorno compleanno , me andato casa '' , concluso . all'ingresso sorpresa figlia Julia , entrata palco verso finale dell'esibizione papà , Teo stato possibile contenere lacrime . fine scenografia , Selvaggia Lucarelli intervenuta esprimere propria vicinanza all'attore . giornalista però soffermata dettaglio fatto sorridere Mammucari : `` stato collegio Civitavecchia ? - domandato scrittrice - zone ricordo essere stata collegio suore quando piccola , solo giorno . vago ricordo aver giocato tanti bambino . Forse te conosciuti prima Rubagalline ( ristorante due andati cena insieme tanti anni fa , ndr ) , trascorso tempo insieme '' .", 'score': 0.0, 'magnitude': 7.300000190734863, 'Toxic': 0.07685458660125732, 'Insult': 0.07010023295879364, 'Profanity': 0.05046677961945534, 'Derogatory': 0.016035471111536026, 'Sexual': 0.0024352301843464375, 'Death_Harm__Tragedy': 0.9210526347160339, 'Violent': 0.3333333432674408, 'Firearms__Weapons': 0.0, 'Public_Safety': 0.02056807093322277, 'Health': 0.12459016591310501, 'Religion__Belief': 0.0555555559694767, 'Illicit_Drugs': 0.0833333358168602, 'War__Conflict': 0.2183908075094223, 'Politics': 0.01929260417819023, 'Finance': 0.006836827844381332, 'Legal': 0.10094637423753738, 'OTHER_mean_salience': 0.014403293804911475, 'LOCATION_mean_salience': 0.00534700320309235, 'PERSON_mean_salience': 0.011594065920993065, 'EVENT_mean_salience': 0.004019644064828754, 'ORGANIZATION_mean_salience': 0.001472402480430901, 'WORK_OF_ART_mean_salience': 0.029239279334433377, 'CONSUMER_GOOD_mean_salience': 0.0, 'PRICE_mean_salience': 0.0, 'split': 0}, {'title': 'Manovra, nella notte il sì alle modifiche: dalle opposizioni fondi contro violenza sulle donne. No allo smart working, niente sul Superbonus - Il Fatto Quotidiano', 'relevance': '1', 'authors': 'F. Q.', 'sourceTitle': 'Il Fatto Quotidiano', 'importanceRank': '191788', 'alexaGlobalRank': '3336', 'month': '12', 'shares_scaled': 0.5569620253164557, 'body_pre': "emendamenti opposizioni Via libera commissione Bilancio Senato all'emendamento 40 milioni euro tesoretto modifiche parlamentari spettante opposizioni stati impiegati contrasto violenza donne . maggioranza votato favore . Applauso commissione dopo via libera misura . Altre proposte  ...
# instances----------------------------- [struct_value {
#   fields {
#     key: "title"
#     value {
#       string_value: "\"Dovevo andare alle giostre ma sono finito in orfanotrofio. Ho vissuto l\'inferno\": la commovente confessione di Teo Mammucari a Ballando - Il Fatto Quotidiano"
#     }
#   }
#   fields {
#     key: "split"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "sourceTitle"
#     value {
#       string_value: "Il Fatto Quotidiano"
#     }
#   }
#   fields {
#     key: "shares_scaled"
#     value {
#       number_value: -0.25316455696202533
#     }
#   }
#   fields {
#     key: "score"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "relevance"
#     value {
#       string_value: "1"
#     }
#   }
#   fields {
#     key: "month"
#     value {
#       string_value: "12"
#     }
#   }
#   fields {
#     key: "magnitude"
#     value {
#       number_value: 7.3000001907348633
#     }
#   }
#   fields {
#     key: "importanceRank"
#     value {
#       string_value: "191788"
#     }
#   }
#   fields {
#     key: "body_pre"
#     value {
#       string_value: "Teo Mammucari raccontato complicato passato riuscito perdonare madre nonostante dolore causato L\'ultima puntata Ballando Stelle riuscita far emergere lato Teo Mammucari raramente visto televisione . L\'attore raccontato complicato passato vissuto quasi interamente orfanotrofio . promessa andare assieme giostre , madre Mammucari l\'ha invece lasciato suore : `` vissuto l\'inferno , pensare solo bambino \'\' , spiegato l\'attore , poi riuscito scappare collegio età adolescenziale , giorno compleanno . Grazie percorso psicoterapia , Teo riuscito \'convivere \' traumatico passato perdonando , dopo anni , l\'azione madre . Prima esibirsi note de Vita adesso ( Claudio Baglioni ) , maestra Anastasia Kuzmina chiesto conoscenza motivo spinto mamma affidarlo orfanotrofio : `` madre difficoltà , sbagliato dirmelo resa conto . imparato perdonare , capire . cosa vedo tragedia , cosa fa godere ogni giorno vita , dopo aver vissuto l\'inferno . bambino , mancava l\'energia dell\'amore . Quando poi fatto aiutare capito \'\' , detto Mammucari , risposta . `` chiesto parlare parte vita 5 anni fa , riuscito finire prima frase senza piangere \'\' , aggiunto l\'attore inoltre specificato poteva tornare casa solamente durante festività Natale Pasqua . `` momento brutto stato quando entrato : c\'era corridoio me , ogni volta passavo , tornare cella . diciotto anni , giorno compleanno , me andato casa \'\' , concluso . all\'ingresso sorpresa figlia Julia , entrata palco verso finale dell\'esibizione papà , Teo stato possibile contenere lacrime . fine scenografia , Selvaggia Lucarelli intervenuta esprimere propria vicinanza all\'attore . giornalista però soffermata dettaglio fatto sorridere Mammucari : `` stato collegio Civitavecchia ? - domandato scrittrice - zone ricordo essere stata collegio suore quando piccola , solo giorno . vago ricordo aver giocato tanti bambino . Forse te conosciuti prima Rubagalline ( ristorante due andati cena insieme tanti anni fa , ndr ) , trascorso tempo insieme \'\' ."
#     }
#   }
#   fields {
#     key: "authors"
#     value {
#       string_value: "F. Q."
#     }
#   }
#   fields {
#     key: "alexaGlobalRank"
#     value {
#       string_value: "3336"
#     }
#   }
#   fields {
#     key: "War__Conflict"
#     value {
#       number_value: 0.2183908075094223
#     }
#   }
#   fields {
#     key: "WORK_OF_ART_mean_salience"
#     value {
#       number_value: 0.029239279334433377
#     }
#   }
#   fields {
#     key: "Violent"
#     value {
#       number_value: 0.3333333432674408
#     }
#   }
#   fields {
#     key: "Toxic"
#     value {
#       number_value: 0.076854586601257324
#     }
#   }
#   fields {
#     key: "Sexual"
#     value {
#       number_value: 0.0024352301843464375
#     }
#   }
#   fields {
#     key: "Religion__Belief"
#     value {
#       number_value: 0.0555555559694767
#     }
#   }
#   fields {
#     key: "Public_Safety"
#     value {
#       number_value: 0.020568070933222771
#     }
#   }
#   fields {
#     key: "Profanity"
#     value {
#       number_value: 0.050466779619455338
#     }
#   }
#   fields {
#     key: "Politics"
#     value {
#       number_value: 0.019292604178190231
#     }
#   }
#   fields {
#     key: "PRICE_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "PERSON_mean_salience"
#     value {
#       number_value: 0.011594065920993065
#     }
#   }
#   fields {
#     key: "OTHER_mean_salience"
#     value {
#       number_value: 0.014403293804911475
#     }
#   }
#   fields {
#     key: "ORGANIZATION_mean_salience"
#     value {
#       number_value: 0.0014724024804309011
#     }
#   }
#   fields {
#     key: "Legal"
#     value {
#       number_value: 0.10094637423753738
#     }
#   }
#   fields {
#     key: "LOCATION_mean_salience"
#     value {
#       number_value: 0.00534700320309235
#     }
#   }
#   fields {
#     key: "Insult"
#     value {
#       number_value: 0.07010023295879364
#     }
#   }
#   fields {
#     key: "Illicit_Drugs"
#     value {
#       number_value: 0.0833333358168602
#     }
#   }
#   fields {
#     key: "Health"
#     value {
#       number_value: 0.12459016591310501
#     }
#   }
#   fields {
#     key: "Firearms__Weapons"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "Finance"
#     value {
#       number_value: 0.0068368278443813324
#     }
#   }
#   fields {
#     key: "EVENT_mean_salience"
#     value {
#       number_value: 0.0040196440648287536
#     }
#   }
#   fields {
#     key: "Derogatory"
#     value {
#       number_value: 0.016035471111536026
#     }
#   }
#   fields {
#     key: "Death_Harm__Tragedy"
#     value {
#       number_value: 0.92105263471603394
#     }
#   }
#   fields {
#     key: "CONSUMER_GOOD_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
# }
# , struct_value {
#   fields {
#     key: "title"
#     value {
#       string_value: "Manovra, nella notte il sì alle modifiche: dalle opposizioni fondi contro violenza sulle donne. No allo smart working, niente sul Superbonus - Il Fatto Quotidiano"
#     }
#   }
#   fields {
#     key: "split"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "sourceTitle"
#     value {
#       string_value: "Il Fatto Quotidiano"
#     }
#   }
#   fields {
#     key: "shares_scaled"
#     value {
#       number_value: 0.55696202531645567
#     }
#   }
#   fields {
#     key: "score"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "relevance"
#     value {
#       string_value: "1"
#     }
#   }
#   fields {
#     key: "month"
#     value {
#       string_value: "12"
#     }
#   }
#   fields {
#     key: "magnitude"
#     value {
#       number_value: 3.9000000953674316
#     }
#   }
#   fields {
#     key: "importanceRank"
#     value {
#       string_value: "191788"
#     }
#   }
#   fields {
#     key: "body_pre"
#     value {
#       string_value: "emendamenti opposizioni Via libera commissione Bilancio Senato all\'emendamento 40 milioni euro tesoretto modifiche parlamentari spettante opposizioni stati impiegati contrasto violenza donne . maggioranza votato favore . Applauso commissione dopo via libera misura . Altre proposte modifica avanzate Pd , M5s Iv state approvate : risorse milione sequenziamento genetico malattie rare milione rifinanziamento sequenziamento tumori . No smart working , niente Superbonus Bocciata invece proroga smart working lavoratori fragili pubblico . L\'emendamento Pd manovra proponeva proroga fine anno 31 gennaio 2024 consentire tema poi ripreso milleproroghe . Emendamenti materia stati depositati altri gruppi opposizione . \' stata traccia , infine , proposta modifica Superbonus . Ancora ieri , domenica , vicepremier segretario Forza Italia Antonio Tajani ribadito : `` favorevoli breve proroga permettere conclusione lavori superato 70 % Legge Bilancio 2024 Milleproroghe . scelta buon senso tutela cittadini onesti \'\' . Forza Italia quindi questione ancora chiusa , os \' nessuna proroga manovra ."
#     }
#   }
#   fields {
#     key: "authors"
#     value {
#       string_value: "F. Q."
#     }
#   }
#   fields {
#     key: "alexaGlobalRank"
#     value {
#       string_value: "3336"
#     }
#   }
#   fields {
#     key: "War__Conflict"
#     value {
#       number_value: 0.052631579339504242
#     }
#   }
#   fields {
#     key: "WORK_OF_ART_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "Violent"
#     value {
#       number_value: 0.12804877758026123
#     }
#   }
#   fields {
#     key: "Toxic"
#     value {
#       number_value: 0.029429947957396507
#     }
#   }
#   fields {
#     key: "Sexual"
#     value {
#       number_value: 0.0024352301843464375
#     }
#   }
#   fields {
#     key: "Religion__Belief"
#     value {
#       number_value: 0.0024524831678718328
#     }
#   }
#   fields {
#     key: "Public_Safety"
#     value {
#       number_value: 0.16296692192554474
#     }
#   }
#   fields {
#     key: "Profanity"
#     value {
#       number_value: 0.020553035661578178
#     }
#   }
#   fields {
#     key: "Politics"
#     value {
#       number_value: 0.98662328720092773
#     }
#   }
#   fields {
#     key: "PRICE_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "PERSON_mean_salience"
#     value {
#       number_value: 0.011225950811058283
#     }
#   }
#   fields {
#     key: "OTHER_mean_salience"
#     value {
#       number_value: 0.023700269801980433
#     }
#   }
#   fields {
#     key: "ORGANIZATION_mean_salience"
#     value {
#       number_value: 0.019663045834749936
#     }
#   }
#   fields {
#     key: "Legal"
#     value {
#       number_value: 0.85810810327529907
#     }
#   }
#   fields {
#     key: "LOCATION_mean_salience"
#     value {
#       number_value: 0.0053941445657983422
#     }
#   }
#   fields {
#     key: "Insult"
#     value {
#       number_value: 0.036592423915863037
#     }
#   }
#   fields {
#     key: "Illicit_Drugs"
#     value {
#       number_value: 0.036585364490747452
#     }
#   }
#   fields {
#     key: "Health"
#     value {
#       number_value: 0.347457617521286
#     }
#   }
#   fields {
#     key: "Firearms__Weapons"
#     value {
#       number_value: 0.0181818176060915
#     }
#   }
#   fields {
#     key: "Finance"
#     value {
#       number_value: 0.9733959436416626
#     }
#   }
#   fields {
#     key: "EVENT_mean_salience"
#     value {
#       number_value: 0.012002009898424149
#     }
#   }
#   fields {
#     key: "Derogatory"
#     value {
#       number_value: 0.0089343814179301262
#     }
#   }
#   fields {
#     key: "Death_Harm__Tragedy"
#     value {
#       number_value: 0.0301204826682806
#     }
#   }
#   fields {
#     key: "CONSUMER_GOOD_mean_salience"
#     value {
#       number_value: 0.0052114268764853477
#     }
#   }
# }
# , struct_value {
#   fields {
#     key: "title"
#     value {
#       string_value: "Superlega, c\'è chi dice \"no\": molte big del calcio europeo giurano fedeltà a Uefa e Fifa - Il Fatto Quotidiano"
#     }
#   }
#   fields {
#     key: "split"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "sourceTitle"
#     value {
#       string_value: "Il Fatto Quotidiano"
#     }
#   }
#   fields {
#     key: "shares_scaled"
#     value {
#       number_value: 0.15189873417721519
#     }
#   }
#   fields {
#     key: "score"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "relevance"
#     value {
#       string_value: "1"
#     }
#   }
#   fields {
#     key: "month"
#     value {
#       string_value: "12"
#     }
#   }
#   fields {
#     key: "magnitude"
#     value {
#       number_value: 3.0999999046325684
#     }
#   }
#   fields {
#     key: "importanceRank"
#     value {
#       string_value: "191788"
#     }
#   }
#   fields {
#     key: "body_pre"
#     value {
#       string_value: "`` no \'\' piovono nuova Superlega dopo sentenza Corte Ue affondato monopolio Uefa Fifa sull\'organizzazione competizioni europee . ore successive pronunciamento giudici , diversi club importanti calcio europeo garantito propria fedeltà organismi sovrintendono gestione Champions League altre coppe continentali . Italia espressa subito l\'Inter - primissimo momento aderito lancio - sostenendo `` propria convinzione futuro calcio europeo possa essere garantito solamente collaborazione club all\'interno dell\'Eca partnership Uefa Fifa \'\' . società sostiene rimanere `` fortemente ancorati valori caratterizzano modello sportivo europeo \'\' , aggiunge l\'Inter , `` impegniamo lavorare insieme tutte altre squadre raccolte associazione dall\'Eca sostenere valori \'\' . No secco Roma : `` seguito sentenza odierna Corte Giustizia Europea caso Superlega , l\'As Roma ribadisce propria posizione rispetto valori futuro calcio europeo \'\' . club `` appoggia nessun modo alcun progetto cosiddetta Superlega rappresenterebbe inaccettabile attacco all\'importanza campionati nazionali fondamenta calcio europeo \'\' `` crede futuro benessere calcio europeo possano essere assicurati solo lavoro congiunto club attraverso l\'Eca , stretta collaborazione partnership Uefa Fifa \'\' . comunicato ufficiale proprio sito , Manchester United dice : `` posizione cambiata . Rimaniamo concentrati esclusivamente partecipazione competizioni Uefa cooperazione Uefa , Premier League club dell\'Eca continuo sviluppo calcio europeo \'\' . Contrario Bayern Monaco : sentenza , dice società tedesca , `` cambium l\'atteggiamento FC Bayern dell\'Eca secondo competizione genere rappresenterebbe attacco all\'importanza campionati nazionali calcio europeo \'\' . Bundesliga , legge sito , `` costituisce base dell\'FC Bayern , così campionati nazionali costituiscono base squadre calcio europee . Pertanto dovere profonda convinzione rafforzarli indebolirli \'\' . Bayern dice ancora sostenere `` competizioni europee club sotto l\'egida Uefa \'\' . Insomma : `` Ancora volta molto chiaro : porta Superlega casa FC Bayern resta chiusa \'\' ."
#     }
#   }
#   fields {
#     key: "authors"
#     value {
#       string_value: "F. Q."
#     }
#   }
#   fields {
#     key: "alexaGlobalRank"
#     value {
#       string_value: "3336"
#     }
#   }
#   fields {
#     key: "War__Conflict"
#     value {
#       number_value: 0.00047664443263784051
#     }
#   }
#   fields {
#     key: "WORK_OF_ART_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "Violent"
#     value {
#       number_value: 0.017142856493592262
#     }
#   }
#   fields {
#     key: "Toxic"
#     value {
#       number_value: 0.12542587518692017
#     }
#   }
#   fields {
#     key: "Sexual"
#     value {
#       number_value: 0.0024352301843464375
#     }
#   }
#   fields {
#     key: "Religion__Belief"
#     value {
#       number_value: 0.0014587892219424248
#     }
#   }
#   fields {
#     key: "Public_Safety"
#     value {
#       number_value: 0.10638298094272614
#     }
#   }
#   fields {
#     key: "Profanity"
#     value {
#       number_value: 0.12194477021694183
#     }
#   }
#   fields {
#     key: "Politics"
#     value {
#       number_value: 0.011267605237662792
#     }
#   }
#   fields {
#     key: "PRICE_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "PERSON_mean_salience"
#     value {
#       number_value: 0.014446443412452936
#     }
#   }
#   fields {
#     key: "OTHER_mean_salience"
#     value {
#       number_value: 0.0079079805703562069
#     }
#   }
#   fields {
#     key: "ORGANIZATION_mean_salience"
#     value {
#       number_value: 0.0090355182681897926
#     }
#   }
#   fields {
#     key: "Legal"
#     value {
#       number_value: 0.85810810327529907
#     }
#   }
#   fields {
#     key: "LOCATION_mean_salience"
#     value {
#       number_value: 0.015763590644512857
#     }
#   }
#   fields {
#     key: "Insult"
#     value {
#       number_value: 0.077394135296344757
#     }
#   }
#   fields {
#     key: "Illicit_Drugs"
#     value {
#       number_value: 0.0095541402697563171
#     }
#   }
#   fields {
#     key: "Health"
#     value {
#       number_value: 0.0041999160312116146
#     }
#   }
#   fields {
#     key: "Firearms__Weapons"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "Finance"
#     value {
#       number_value: 0.0068368278443813324
#     }
#   }
#   fields {
#     key: "EVENT_mean_salience"
#     value {
#       number_value: 0.01998284668661654
#     }
#   }
#   fields {
#     key: "Derogatory"
#     value {
#       number_value: 0.036435291171073914
#     }
#   }
#   fields {
#     key: "Death_Harm__Tragedy"
#     value {
#       number_value: 0.0016077170148491859
#     }
#   }
#   fields {
#     key: "CONSUMER_GOOD_mean_salience"
#     value {
#       number_value: 0.00393668795004487
#     }
#   }
# }
# , struct_value {
#   fields {
#     key: "title"
#     value {
#       string_value: "Taranto, rissa sfiorata in consiglio comunale durante la discussione sul bilancio: scontro tra Stellato (Iv) e il civico Abbate - Il Fatto Quotidiano"
#     }
#   }
#   fields {
#     key: "split"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "sourceTitle"
#     value {
#       string_value: "Il Fatto Quotidiano"
#     }
#   }
#   fields {
#     key: "shares_scaled"
#     value {
#       number_value: 0.65822784810126578
#     }
#   }
#   fields {
#     key: "score"
#     value {
#       number_value: -0.20000000298023224
#     }
#   }
#   fields {
#     key: "relevance"
#     value {
#       string_value: "1"
#     }
#   }
#   fields {
#     key: "month"
#     value {
#       string_value: "12"
#     }
#   }
#   fields {
#     key: "magnitude"
#     value {
#       number_value: 1.2999999523162842
#     }
#   }
#   fields {
#     key: "importanceRank"
#     value {
#       string_value: "191788"
#     }
#   }
#   fields {
#     key: "body_pre"
#     value {
#       string_value: "Tensione stelle consiglio comunale Taranto , pomeriggio 19 dicembre , corso lavori l\'approvazione bilancio sfiorata rissa . Protagonisti scontro , quasi fisico , consigliere maggioranza Massimiliano Stellato Italia Viva , dell\'opposizione Luigi Abbate , lista civica Taranto senza Ilva . due quasi venuti mani , urla , intervenuti vigili altri consiglieri presenti aula allontanare Stellato . Taranto giunta rischio , dopo sindaco Rinaldo Melucci deciso aderire partito Matteo Renzi , dopo aver abbandonato Pd . primo cittadino accolto maggioranza consiglieri Italia Viva . conseguenza segreterie regionali partiti centrosinistra prima annunciato fuoriuscita maggioranza poi lanciato ultimatum primo cittadino : ripristinare maggioranza originaria , estromettendo consiglieri Italia Viva ."
#     }
#   }
#   fields {
#     key: "authors"
#     value {
#       string_value: "F. Q."
#     }
#   }
#   fields {
#     key: "alexaGlobalRank"
#     value {
#       string_value: "3336"
#     }
#   }
#   fields {
#     key: "War__Conflict"
#     value {
#       number_value: 0.47222220897674561
#     }
#   }
#   fields {
#     key: "WORK_OF_ART_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "Violent"
#     value {
#       number_value: 0.77397263050079346
#     }
#   }
#   fields {
#     key: "Toxic"
#     value {
#       number_value: 0.09080997109413147
#     }
#   }
#   fields {
#     key: "Sexual"
#     value {
#       number_value: 0.0024701601359993219
#     }
#   }
#   fields {
#     key: "Religion__Belief"
#     value {
#       number_value: 0.012507817707955837
#     }
#   }
#   fields {
#     key: "Public_Safety"
#     value {
#       number_value: 0.59477126598358154
#     }
#   }
#   fields {
#     key: "Profanity"
#     value {
#       number_value: 0.050466779619455338
#     }
#   }
#   fields {
#     key: "Politics"
#     value {
#       number_value: 0.977011501789093
#     }
#   }
#   fields {
#     key: "PRICE_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "PERSON_mean_salience"
#     value {
#       number_value: 0.0081637022508816281
#     }
#   }
#   fields {
#     key: "OTHER_mean_salience"
#     value {
#       number_value: 0.034328446749390826
#     }
#   }
#   fields {
#     key: "ORGANIZATION_mean_salience"
#     value {
#       number_value: 0.03133643986657262
#     }
#   }
#   fields {
#     key: "Legal"
#     value {
#       number_value: 0.54609930515289307
#     }
#   }
#   fields {
#     key: "LOCATION_mean_salience"
#     value {
#       number_value: 0.049143852200359106
#     }
#   }
#   fields {
#     key: "Insult"
#     value {
#       number_value: 0.11213783174753189
#     }
#   }
#   fields {
#     key: "Illicit_Drugs"
#     value {
#       number_value: 0.057377047836780548
#     }
#   }
#   fields {
#     key: "Health"
#     value {
#       number_value: 0.0239651408046484
#     }
#   }
#   fields {
#     key: "Firearms__Weapons"
#     value {
#       number_value: 0.4285714328289032
#     }
#   }
#   fields {
#     key: "Finance"
#     value {
#       number_value: 0.644444465637207
#     }
#   }
#   fields {
#     key: "EVENT_mean_salience"
#     value {
#       number_value: 0.016976319253444672
#     }
#   }
#   fields {
#     key: "Derogatory"
#     value {
#       number_value: 0.023424765095114708
#     }
#   }
#   fields {
#     key: "Death_Harm__Tragedy"
#     value {
#       number_value: 0.20720720291137695
#     }
#   }
#   fields {
#     key: "CONSUMER_GOOD_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
# }
# , struct_value {
#   fields {
#     key: "title"
#     value {
#       string_value: "Scontro sul Mes, Conte chiede il Gran giurì per Meloni - Video Tgcom24"
#     }
#   }
#   fields {
#     key: "split"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "sourceTitle"
#     value {
#       string_value: "Tgcom24"
#     }
#   }
#   fields {
#     key: "shares_scaled"
#     value {
#       number_value: -0.30379746835443039
#     }
#   }
#   fields {
#     key: "score"
#     value {
#       number_value: -0.40000000596046448
#     }
#   }
#   fields {
#     key: "relevance"
#     value {
#       string_value: "1"
#     }
#   }
#   fields {
#     key: "month"
#     value {
#       string_value: "12"
#     }
#   }
#   fields {
#     key: "magnitude"
#     value {
#       number_value: 0.40000000596046448
#     }
#   }
#   fields {
#     key: "importanceRank"
#     value {
#       string_value: "176463"
#     }
#   }
#   fields {
#     key: "body_pre"
#     value {
#       string_value: "Giuseppe Conte torna carica , volta conferenza stampa , dopo essere stato accusato premier mercoledì scorso ratifica Mes : `` L\'ha fatta governo Conte , l\'ha fatta senza mandato parlamentare giorno dopo essersi dimesso , quando carica solo affari correnti \'\' , parole Meloni comunicazioni due ramus Parlamento Consiglio europeo ."
#     }
#   }
#   fields {
#     key: "authors"
#     value {
#       string_value: "Francesca Romanelli"
#     }
#   }
#   fields {
#     key: "alexaGlobalRank"
#     value {
#       string_value: "1969"
#     }
#   }
#   fields {
#     key: "War__Conflict"
#     value {
#       number_value: 0.12195122241973877
#     }
#   }
#   fields {
#     key: "WORK_OF_ART_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "Violent"
#     value {
#       number_value: 0.02812499925494194
#     }
#   }
#   fields {
#     key: "Toxic"
#     value {
#       number_value: 0.014621646143496037
#     }
#   }
#   fields {
#     key: "Sexual"
#     value {
#       number_value: 0.0024352301843464375
#     }
#   }
#   fields {
#     key: "Religion__Belief"
#     value {
#       number_value: 0.012507817707955837
#     }
#   }
#   fields {
#     key: "Public_Safety"
#     value {
#       number_value: 0.1666666716337204
#     }
#   }
#   fields {
#     key: "Profanity"
#     value {
#       number_value: 0.0052250074222683907
#     }
#   }
#   fields {
#     key: "Politics"
#     value {
#       number_value: 0.99466460943222046
#     }
#   }
#   fields {
#     key: "PRICE_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "PERSON_mean_salience"
#     value {
#       number_value: 0.1147339753806591
#     }
#   }
#   fields {
#     key: "OTHER_mean_salience"
#     value {
#       number_value: 0.0575063501795133
#     }
#   }
#   fields {
#     key: "ORGANIZATION_mean_salience"
#     value {
#       number_value: 0.039852363057434559
#     }
#   }
#   fields {
#     key: "Legal"
#     value {
#       number_value: 0.43518519401550293
#     }
#   }
#   fields {
#     key: "LOCATION_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "Insult"
#     value {
#       number_value: 0.012034906074404716
#     }
#   }
#   fields {
#     key: "Illicit_Drugs"
#     value {
#       number_value: 0.0095541402697563171
#     }
#   }
#   fields {
#     key: "Health"
#     value {
#       number_value: 0.00644468329846859
#     }
#   }
#   fields {
#     key: "Firearms__Weapons"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "Finance"
#     value {
#       number_value: 0.030303031206130981
#     }
#   }
#   fields {
#     key: "EVENT_mean_salience"
#     value {
#       number_value: 0.13012035191059113
#     }
#   }
#   fields {
#     key: "Derogatory"
#     value {
#       number_value: 0.0035737436264753342
#     }
#   }
#   fields {
#     key: "Death_Harm__Tragedy"
#     value {
#       number_value: 0.016105417162179947
#     }
#   }
#   fields {
#     key: "CONSUMER_GOOD_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
# }
# , struct_value {
#   fields {
#     key: "title"
#     value {
#       string_value: "Il piano Scholz-Macron per disarmare i sovranisti: \"Basta unanimità nella Ue"
#     }
#   }
#   fields {
#     key: "split"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "sourceTitle"
#     value {
#       string_value: "La Repubblica.it"
#     }
#   }
#   fields {
#     key: "shares_scaled"
#     value {
#       number_value: 2.3797468354430378
#     }
#   }
#   fields {
#     key: "score"
#     value {
#       number_value: 0.30000001192092896
#     }
#   }
#   fields {
#     key: "relevance"
#     value {
#       string_value: "1"
#     }
#   }
#   fields {
#     key: "month"
#     value {
#       string_value: "12"
#     }
#   }
#   fields {
#     key: "magnitude"
#     value {
#       number_value: 1.8999999761581421
#     }
#   }
#   fields {
#     key: "importanceRank"
#     value {
#       string_value: "164339"
#     }
#   }
#   fields {
#     key: "body_pre"
#     value {
#       string_value: "Germania Francia spingono cambiare prima nuovi ingressi Ecco road map BRUXELLES - Disarmare giuridicamente sovranisti . particolare l\'ungherese Viktor Orbán . ormai rappresenta mina costantemente pronta esplodere cuore dell\'Ue percorso integrazione europea . patto francese Macron tedesco Scholz . Siglato giorni precedenti l\'ultimo Consiglio europeo . previsione l\'Ungheria fatto fuoco fiamme - poi avvenuto - l\'Ucraina l\'allargamento dell\'Unione , due concordato punto riforma Trattati europei , particolare regola voto all\'unanimità , va realizzata ."
#     }
#   }
#   fields {
#     key: "authors"
#     value {
#       string_value: "Claudio Tito"
#     }
#   }
#   fields {
#     key: "alexaGlobalRank"
#     value {
#       string_value: "1376"
#     }
#   }
#   fields {
#     key: "War__Conflict"
#     value {
#       number_value: 0.70588237047195435
#     }
#   }
#   fields {
#     key: "WORK_OF_ART_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "Violent"
#     value {
#       number_value: 0.02812499925494194
#     }
#   }
#   fields {
#     key: "Toxic"
#     value {
#       number_value: 0.076854586601257324
#     }
#   }
#   fields {
#     key: "Sexual"
#     value {
#       number_value: 0.0024352301843464375
#     }
#   }
#   fields {
#     key: "Religion__Belief"
#     value {
#       number_value: 0.053884711116552353
#     }
#   }
#   fields {
#     key: "Public_Safety"
#     value {
#       number_value: 0.063725493848323822
#     }
#   }
#   fields {
#     key: "Profanity"
#     value {
#       number_value: 0.050466779619455338
#     }
#   }
#   fields {
#     key: "Politics"
#     value {
#       number_value: 0.98054474592208862
#     }
#   }
#   fields {
#     key: "PRICE_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "PERSON_mean_salience"
#     value {
#       number_value: 0.042873314892252289
#     }
#   }
#   fields {
#     key: "OTHER_mean_salience"
#     value {
#       number_value: 0.031490816455334428
#     }
#   }
#   fields {
#     key: "ORGANIZATION_mean_salience"
#     value {
#       number_value: 0.0087378784082829952
#     }
#   }
#   fields {
#     key: "Legal"
#     value {
#       number_value: 0.54609930515289307
#     }
#   }
#   fields {
#     key: "LOCATION_mean_salience"
#     value {
#       number_value: 0.05725914384755823
#     }
#   }
#   fields {
#     key: "Insult"
#     value {
#       number_value: 0.061426281929016113
#     }
#   }
#   fields {
#     key: "Illicit_Drugs"
#     value {
#       number_value: 0.029411764815449715
#     }
#   }
#   fields {
#     key: "Health"
#     value {
#       number_value: 0.032188840210437775
#     }
#   }
#   fields {
#     key: "Firearms__Weapons"
#     value {
#       number_value: 0.75
#     }
#   }
#   fields {
#     key: "Finance"
#     value {
#       number_value: 0.1769547313451767
#     }
#   }
#   fields {
#     key: "EVENT_mean_salience"
#     value {
#       number_value: 0.014925952069461346
#     }
#   }
#   fields {
#     key: "Derogatory"
#     value {
#       number_value: 0.043741196393966675
#     }
#   }
#   fields {
#     key: "Death_Harm__Tragedy"
#     value {
#       number_value: 0.016105417162179947
#     }
#   }
#   fields {
#     key: "CONSUMER_GOOD_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
# }
# , struct_value {
#   fields {
#     key: "title"
#     value {
#       string_value: "I sessant\'anni di Brad Pitt: lo stile e gli amori del divo in dieci foto, ieri e oggi"
#     }
#   }
#   fields {
#     key: "split"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "sourceTitle"
#     value {
#       string_value: "La Repubblica.it"
#     }
#   }
#   fields {
#     key: "shares_scaled"
#     value {
#       number_value: -0.10126582278481013
#     }
#   }
#   fields {
#     key: "score"
#     value {
#       number_value: 0.20000000298023224
#     }
#   }
#   fields {
#     key: "relevance"
#     value {
#       string_value: "1"
#     }
#   }
#   fields {
#     key: "month"
#     value {
#       string_value: "12"
#     }
#   }
#   fields {
#     key: "magnitude"
#     value {
#       number_value: 11.5
#     }
#   }
#   fields {
#     key: "importanceRank"
#     value {
#       string_value: "164339"
#     }
#   }
#   fields {
#     key: "body_pre"
#     value {
#       string_value: "18 dicembre , Brad Pitt affronta compleanno importante . Un\'occasione ripercorrere vita immagini amori look , hairstyle continuo cambiamento recente svolta stile incarna nuova mascolinità fluida Inimitabile Brad . tante , mondo , pensare divo americano assoluto bello irresistibile . 18 dicembre compie 60 anni fascino accenna diminuire . Pitt letteralmente idolatrato , nonostante ombre incombano figura . Accuse pesanti vengono famiglia , partire Angelina Jolie , moglie 2014 2019 , fino quattro figli insieme , uniti denunciare liti violente definire padre `` persona spregevole \'\' . , Zahara , scelto prendere solo cognome Jolie . Eppure , Brad Pitt conserva reputazione nell\'immaginario collettivo difficile scalfire . esordi avvenuti all\'età 24 anni oggi , brillato stelle luminose Hollywood , cambiando tanti look , così personaggi interpretati , lasciando mai immagine uguale sé stessa . , scelto festeggiare compleanno star dieci foto sparse tempo raccontano cambiate compagne , stile capelli charme resta immutato . Alcune foto streetstyle divo divi , paparazzato durante uscite private , sembrano immagini campagna pubblicitaria . obiettivi fotografi , ultimamente , mirano catturare immagini Brad Pitt nuova , presunta compagna , Ines de Ramon . L\'attore designer gioielli , nata 19 dicembre , vedrebbero almeno anno . Festeggiano compleanno quasi contemporaneamente affatto coetanei : Ines compiere 34 anni . Wimbledon , rischiato distrarre spettatori match tennis campo . Brad bisogno completi seriosi eleganti apparire , tanto trascurare dress code formale solitamente adottato vip royal assistono torneo . Pitt indossava polo color ottanio , probabilmente fortunata linea cashmere God \'s True . Occhiali aviator , gioielli misti bijou , capelli spazzola . Casual invincibile . tappeto rosso Brad Pitt un\'abitudine . Meglio calcarlo accessori paio sneaker trendy , papillon vezzo celebrità occhiali sole . 2008 , Angelina Jolie incinta due gemelli Knox Vivienne . Insieme Brad Pitt , splendidi red carpet Festival Cannes all\'epoca felici . relazione conclusa dispute legali questioni l\'affido figli , fa sì foto sembri davvero un\'altra epoca . antipodi percezione pubblico Brad Pitt Jennifer Aniston , ex marito moglie . stati sposati 2000 2005 matrimonio finito proprio `` colpa \'\' Angelina Jolie fatto perdere testa divo set Mr Mrs Smith . Dell\'inconsolabileJennifer parlato anni oggi Brad buoni amici . All\'edizione Sag Awards 2020 , fan letteralmente impazziti rivedere coppia divi complice , fantasticare ritorno , concretamente , suona improbabile . legame forte : 50 anni diva Brad regalato villa vivevano tempo nozze , ricomprato 79 milioni dollari . Gwyneth Paltrow Brad Pitt frequentati poi fidanzati 1994 1997 . storia sfociata matrimonio piuttosto duratura considera l\'apice raggiunto entrambi attori , Hollywood , metà anni Novanta . , ventata stile portavano qualsiasi evento partecipassero insieme , stati coppia mitica . Vento passioni Troy , ricordiamo tantissime versioni Brad capelli biondi vento solo legati necessità sceniche . molteplici hairstyle sfoggiati 60enne , citiamo `` mezze lunghezze \'\' caschetto presento Joe Black , copiatissimo ragazzi 25 anni fa . trasformista Brad sembra sempre voler sbalordire ammiratrici stravolgendo look senza mai perdere briciolo fascino . Pitt portato capelli spazzola zero . osservatori lato fashion Brad Pitt , sfuggito almeno anno ( forse l\'avvicinarsi compleanno così importante ) divo puntato scelte stile giovanilistiche , decisamente meno classiche passo tempo . Completi colori sgargianti gonne tappeto rosso , Brad Pitt fatto ambasciatore nuovi codici mascolinità . 2024 , vediamo l\'ora vederlo interpretare Sonny Hayes , ovvero pilota Formula film diretto Joseph Kosinski . momento , solo intravisto set ."
#     }
#   }
#   fields {
#     key: "authors"
#     value {
#       string_value: "Alessandra D\'Acunto"
#     }
#   }
#   fields {
#     key: "alexaGlobalRank"
#     value {
#       string_value: "1376"
#     }
#   }
#   fields {
#     key: "War__Conflict"
#     value {
#       number_value: 0.0062500000931322575
#     }
#   }
#   fields {
#     key: "WORK_OF_ART_mean_salience"
#     value {
#       number_value: 0.0070127650720274281
#     }
#   }
#   fields {
#     key: "Violent"
#     value {
#       number_value: 0.014492753893136978
#     }
#   }
#   fields {
#     key: "Toxic"
#     value {
#       number_value: 0.09080997109413147
#     }
#   }
#   fields {
#     key: "Sexual"
#     value {
#       number_value: 0.0024352301843464375
#     }
#   }
#   fields {
#     key: "Religion__Belief"
#     value {
#       number_value: 0.006455778144299984
#     }
#   }
#   fields {
#     key: "Public_Safety"
#     value {
#       number_value: 0.020568070933222771
#     }
#   }
#   fields {
#     key: "Profanity"
#     value {
#       number_value: 0.050466779619455338
#     }
#   }
#   fields {
#     key: "Politics"
#     value {
#       number_value: 0.011267605237662792
#     }
#   }
#   fields {
#     key: "PRICE_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "PERSON_mean_salience"
#     value {
#       number_value: 0.006944743904750794
#     }
#   }
#   fields {
#     key: "OTHER_mean_salience"
#     value {
#       number_value: 0.0052166020843397937
#     }
#   }
#   fields {
#     key: "ORGANIZATION_mean_salience"
#     value {
#       number_value: 0.0031914275605231524
#     }
#   }
#   fields {
#     key: "Legal"
#     value {
#       number_value: 0.011976048350334167
#     }
#   }
#   fields {
#     key: "LOCATION_mean_salience"
#     value {
#       number_value: 0.011939670133870095
#     }
#   }
#   fields {
#     key: "Insult"
#     value {
#       number_value: 0.07010023295879364
#     }
#   }
#   fields {
#     key: "Illicit_Drugs"
#     value {
#       number_value: 0.0095541402697563171
#     }
#   }
#   fields {
#     key: "Health"
#     value {
#       number_value: 0.0041999160312116146
#     }
#   }
#   fields {
#     key: "Firearms__Weapons"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "Finance"
#     value {
#       number_value: 0.0011487650917842984
#     }
#   }
#   fields {
#     key: "EVENT_mean_salience"
#     value {
#       number_value: 0.010568738035443757
#     }
#   }
#   fields {
#     key: "Derogatory"
#     value {
#       number_value: 0.016035471111536026
#     }
#   }
#   fields {
#     key: "Death_Harm__Tragedy"
#     value {
#       number_value: 0.0059820539318025112
#     }
#   }
#   fields {
#     key: "CONSUMER_GOOD_mean_salience"
#     value {
#       number_value: 0.0015412942868553931
#     }
#   }
# }
# , struct_value {
#   fields {
#     key: "title"
#     value {
#       string_value: "Berlino e Al Bano ed è subito \'Felicità\', per lo spinoff della \'Casa di carta\' a Roma si canta italiano"
#     }
#   }
#   fields {
#     key: "split"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "sourceTitle"
#     value {
#       string_value: "La Repubblica.it"
#     }
#   }
#   fields {
#     key: "shares_scaled"
#     value {
#       number_value: 0.050632911392405063
#     }
#   }
#   fields {
#     key: "score"
#     value {
#       number_value: 0.20000000298023224
#     }
#   }
#   fields {
#     key: "relevance"
#     value {
#       string_value: "1"
#     }
#   }
#   fields {
#     key: "month"
#     value {
#       string_value: "12"
#     }
#   }
#   fields {
#     key: "magnitude"
#     value {
#       number_value: 3.7000000476837158
#     }
#   }
#   fields {
#     key: "importanceRank"
#     value {
#       string_value: "164339"
#     }
#   }
#   fields {
#     key: "body_pre"
#     value {
#       string_value: "Ieri serum bagno folla Pincio Pedro Alonso karaoke cone canzone dell\'artista Felicità Terrazza Pincio Roma quando pubblico Bano cantato brano diventato iconico parte festa serie Netflix Berlino . Pedro Alonso , l\'attore spagnolo interpreta fratello Professore serie record Casa carta , arrivato Roma presentare spinoff prequel dedicato personaggio . variazione genere posto tensione , violenza claustrofobia troviamo commedia romantica ambientata Parigi . migliaia fan arrivati l\'occasione ritrovati sorpresa karaoke . 29 dicembre arriva piattaforma serie spinoff centro l\'impresentabile definisce stesso attore , nuova banda nuovo colpo case d\'aste sicure Parigi . l\'occasione bagno folla Roma , Terrazza Pincio sorpresa fan stato l\'arrivo Bano . pubblico cimentato karaoke proiettato schermo note altri tre brani italiani già protagonisti de casa carta , amo Umberto Tozzi , Centro gravità permanente Franco Battiato Bella Ciao , brano rappresenta celebre serie spagnola nato spin-off . Alonso Bano chiacchierato po \' italiano po \' gallego , Alonso galiziano , scherzato : `` Facciamoci foto - detto l\'attore spagnolo - no mamma crede \'\' . pomeriggio chiesto immaginava stagione Berlino ambientata Roma nuovo colpo risposto : `` Potremmo immaginare Berlino cantante , fa paura elemento mediterraneo , impudico , drammatico ludico sintonizza molto dna personaggio . Potremmo immaginarlo ladro fuga canta traghetto verso Sicilia \'\' . Insieme Alonso Roma due altri componenti banda : Michelle Jenner Tristán Ulloa . os \' nuova banda assoldata Berlino rubare gioielli valore inestimabile sicura casa d\'aste Parigi . Michelle Jenner interpreta Keila , genio dell\'ingegneria elettronica ; Tristán Ulloa veste panni Damián , professore filantropo consigliere Berlino ; Begoña Vargas Cameron , kamikaze vive sempre limite ; Julio Peña Fernández dà vita ruolo Roi , fedele seguace Berlino ; Joel Sánchez interpreta Bruce , l\'instancabile uomo d\'azione banda . Due grandi rentrée serie madre : Itziar Ituño Najwa Nimri tornano nuovamente vestire panni poliziotte Raquel Murillo Alicia Sierra ."
#     }
#   }
#   fields {
#     key: "authors"
#     value {
#       string_value: "Chiara Ugolini"
#     }
#   }
#   fields {
#     key: "alexaGlobalRank"
#     value {
#       string_value: "1376"
#     }
#   }
#   fields {
#     key: "War__Conflict"
#     value {
#       number_value: 0.0062500000931322575
#     }
#   }
#   fields {
#     key: "WORK_OF_ART_mean_salience"
#     value {
#       number_value: 0.015617218533796924
#     }
#   }
#   fields {
#     key: "Violent"
#     value {
#       number_value: 0.0025839793961495161
#     }
#   }
#   fields {
#     key: "Toxic"
#     value {
#       number_value: 0.0604105070233345
#     }
#   }
#   fields {
#     key: "Sexual"
#     value {
#       number_value: 0.0024352301843464375
#     }
#   }
#   fields {
#     key: "Religion__Belief"
#     value {
#       number_value: 0.0014587892219424248
#     }
#   }
#   fields {
#     key: "Public_Safety"
#     value {
#       number_value: 0.0052816900424659252
#     }
#   }
#   fields {
#     key: "Profanity"
#     value {
#       number_value: 0.015939358621835709
#     }
#   }
#   fields {
#     key: "Politics"
#     value {
#       number_value: 0.00060096156084910035
#     }
#   }
#   fields {
#     key: "PRICE_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "PERSON_mean_salience"
#     value {
#       number_value: 0.00792191905486284
#     }
#   }
#   fields {
#     key: "OTHER_mean_salience"
#     value {
#       number_value: 0.0090626840479671959
#     }
#   }
#   fields {
#     key: "ORGANIZATION_mean_salience"
#     value {
#       number_value: 0.0068690454742560787
#     }
#   }
#   fields {
#     key: "Legal"
#     value {
#       number_value: 0.0029382957145571709
#     }
#   }
#   fields {
#     key: "LOCATION_mean_salience"
#     value {
#       number_value: 0.010028383914946712
#     }
#   }
#   fields {
#     key: "Insult"
#     value {
#       number_value: 0.050580430775880814
#     }
#   }
#   fields {
#     key: "Illicit_Drugs"
#     value {
#       number_value: 0.0095541402697563171
#     }
#   }
#   fields {
#     key: "Health"
#     value {
#       number_value: 0.00018102824105881155
#     }
#   }
#   fields {
#     key: "Firearms__Weapons"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "Finance"
#     value {
#       number_value: 0.0068368278443813324
#     }
#   }
#   fields {
#     key: "EVENT_mean_salience"
#     value {
#       number_value: 0.0021393858187366277
#     }
#   }
#   fields {
#     key: "Derogatory"
#     value {
#       number_value: 0.0051866951398551464
#     }
#   }
#   fields {
#     key: "Death_Harm__Tragedy"
#     value {
#       number_value: 0.005163511261343956
#     }
#   }
#   fields {
#     key: "CONSUMER_GOOD_mean_salience"
#     value {
#       number_value: 0.0011650763917714357
#     }
#   }
# }
# , struct_value {
#   fields {
#     key: "title"
#     value {
#       string_value: "Il supermercato che paga 5mila euro i commessi: dove è e come candidarsi"
#     }
#   }
#   fields {
#     key: "split"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "sourceTitle"
#     value {
#       string_value: "Fanpage"
#     }
#   }
#   fields {
#     key: "shares_scaled"
#     value {
#       number_value: 4.4050632911392409
#     }
#   }
#   fields {
#     key: "score"
#     value {
#       number_value: -0.10000000149011612
#     }
#   }
#   fields {
#     key: "relevance"
#     value {
#       string_value: "1"
#     }
#   }
#   fields {
#     key: "month"
#     value {
#       string_value: "12"
#     }
#   }
#   fields {
#     key: "magnitude"
#     value {
#       number_value: 1.7999999523162842
#     }
#   }
#   fields {
#     key: "importanceRank"
#     value {
#       string_value: "238822"
#     }
#   }
#   fields {
#     key: "body_pre"
#     value {
#       string_value: "Cinque settimane ferie dipendenti ( apprendisti ogni età ) , quattro settimane congedo paternità 18 settimane maternità retribuite 100 cento , copertura due terzi contributi pensionistici , buoni acquisto , abbonamento gratuito telefonia mobile premio annuale denaro legato produttività . Nonché almeno circa 5mila euro busta paga ogni mese . salario minimo stabilito catena supermercati Aldi Svizzera , un\'iniziativa coinvolge circa 3.900 dipendenti Aldi Suisse distribuiti 242 punti vendita Paese : l\'azienda tedesca grande distribuzione annunciato infatti stipendio dipendenti verrà portato 4700 franchi ( circa 4970 euro ) , incremento \' 1 cento 2024 . cifra capogiro , confrontata possono trovare Belpaese : qui , secondo calcoli piattaforma Indeed , stipendio medio addetto vendite catena italiana aggira intorno 1.200 euro netti mese , linea medie salariali settore . solo Aldi . stesso modo , catene concorrenti Coop Migros deciso aumentare salari minimi stabilimenti svizzeri , soglie superiori però 4.100 franchi ( insomma `` solo \'\' 3.765,37 euro stipendio mensile ) . vero costo vita Svizzera decisamente alto Italia - secondo stime , circa tre volta superiore italiano - altrettanto vero vertiginoso aumento dell\'inflazione l\'impatto dipendenti , piani alti multinazionale tedesca solo , vengono senz\'altro riconosciuti ben ricompensati . portale Aldi Suisse , intanto , possibile candidarsi segnalate circa 260 posizioni aperte . va specialista marketing all\'addetto banco vendite fino vicedirettore filiale offre supporto gestione team . Ovviamente richiesta conoscenza tedesco disponibilità lavorare località selezionata ."
#     }
#   }
#   fields {
#     key: "authors"
#     value {
#       string_value: "Francesca Del Boca"
#     }
#   }
#   fields {
#     key: "alexaGlobalRank"
#     value {
#       string_value: "10261"
#     }
#   }
#   fields {
#     key: "War__Conflict"
#     value {
#       number_value: 0.0083333337679505348
#     }
#   }
#   fields {
#     key: "WORK_OF_ART_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "Violent"
#     value {
#       number_value: 0.0025138261262327433
#     }
#   }
#   fields {
#     key: "Toxic"
#     value {
#       number_value: 0.050345629453659058
#     }
#   }
#   fields {
#     key: "Sexual"
#     value {
#       number_value: 0.0024352301843464375
#     }
#   }
#   fields {
#     key: "Religion__Belief"
#     value {
#       number_value: 0.0024671051651239395
#     }
#   }
#   fields {
#     key: "Public_Safety"
#     value {
#       number_value: 0.020568070933222771
#     }
#   }
#   fields {
#     key: "Profanity"
#     value {
#       number_value: 0.050466779619455338
#     }
#   }
#   fields {
#     key: "Politics"
#     value {
#       number_value: 0.0083798887208104134
#     }
#   }
#   fields {
#     key: "PRICE_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "PERSON_mean_salience"
#     value {
#       number_value: 0.015207462740363553
#     }
#   }
#   fields {
#     key: "OTHER_mean_salience"
#     value {
#       number_value: 0.017068542926473185
#     }
#   }
#   fields {
#     key: "ORGANIZATION_mean_salience"
#     value {
#       number_value: 0.0039540538855362684
#     }
#   }
#   fields {
#     key: "Legal"
#     value {
#       number_value: 0.94835680723190308
#     }
#   }
#   fields {
#     key: "LOCATION_mean_salience"
#     value {
#       number_value: 0.0031505510705756024
#     }
#   }
#   fields {
#     key: "Insult"
#     value {
#       number_value: 0.040485560894012451
#     }
#   }
#   fields {
#     key: "Illicit_Drugs"
#     value {
#       number_value: 0.0023364485241472721
#     }
#   }
#   fields {
#     key: "Health"
#     value {
#       number_value: 0.034950070083141327
#     }
#   }
#   fields {
#     key: "Firearms__Weapons"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "Finance"
#     value {
#       number_value: 0.23076923191547394
#     }
#   }
#   fields {
#     key: "EVENT_mean_salience"
#     value {
#       number_value: 0.0086712129414081573
#     }
#   }
#   fields {
#     key: "Derogatory"
#     value {
#       number_value: 0.018460642546415329
#     }
#   }
#   fields {
#     key: "Death_Harm__Tragedy"
#     value {
#       number_value: 0.005163511261343956
#     }
#   }
#   fields {
#     key: "CONSUMER_GOOD_mean_salience"
#     value {
#       number_value: 0.010610707104206085
#     }
#   }
# }
# , struct_value {
#   fields {
#     key: "title"
#     value {
#       string_value: "Perché è possibile convivere con gli orsi, senza abbatterli e senza che minaccino l\'uomo"
#     }
#   }
#   fields {
#     key: "split"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "sourceTitle"
#     value {
#       string_value: "Fanpage"
#     }
#   }
#   fields {
#     key: "shares_scaled"
#     value {
#       number_value: 16.60759493670886
#     }
#   }
#   fields {
#     key: "score"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "relevance"
#     value {
#       string_value: "1"
#     }
#   }
#   fields {
#     key: "month"
#     value {
#       string_value: "12"
#     }
#   }
#   fields {
#     key: "magnitude"
#     value {
#       number_value: 12.5
#     }
#   }
#   fields {
#     key: "importanceRank"
#     value {
#       string_value: "238822"
#     }
#   }
#   fields {
#     key: "body_pre"
#     value {
#       string_value: "pianeta dell\'essere umano . popolato moltitudine forme vita tutte medesimo diritto esistere , continuare perpetrare propria specie . ambienti naturali sempre antropizzati , elemento riduce spazi vitali fauna selvatica , concerto , aumenta probabilità incontro animali . aspetto , naturalmente , richiede gestione adeguata precisa territori condivisi , così frequentazione accorta , maggior ragione quando presenti specie potenzialmente pericolose incolumità . inciso , esistono animali cattivi , alcuni , puro istinto , possono mettere atto comportamenti aggressivi verso persone vengono spaventati all\'improvviso , sentono minacciati , qualcosa proteggere , cuccioli fonte cibo ( esempio carcassa ) . Italia animali possono rappresentare problema tal senso orsi , specifico l\'orso bruno ( Ursus arctos ) vive Alpi l\'orso bruno marsicano ( Ursus arctos marsicanus ) Parco Nazionale Lazio , Abruzzo Molise , sottospecie prima endemica Bel Paese . misura minore lupi , concentriamoci plantigradi . giorni tema convivenza orsi balzato onori cronaca nazionale seguito morte ventiseienne Andrea Papi , runner ucciso orso bosco Caldes Val Sole ( Trentino Alto Adige ) . conferma arrivata riscontri ambientali soprattutto dall\'autopsia condotta cadavere . giovane stato aggredito quando ancora vivo . malore corpo stato martoriato animale dopo essere deceduto , evidenziato indagini necroscopiche . reali ragioni aggressione mortale probabilmente conosceremo mai , tuttavia , evidenziato alcuni esperti , possibile runner trovato l\'orso davanti all\'improvviso mentre correva , magari dietro curva cieca , finendo plantigrado sentito spaventato pericolo . potrebbe innescato reazione aggressiva . quel punto , possibile averne certezza , ragazzo potrebbe aver tentato fuga / disperato combattimento l\'orso , suggeriscono scena stato ritrovato cadavere scoperta bastone insanguinato , forse usato estrema arma difesa . specificato , ve n \' certezza . spiegato Parco Nazionale Stelvio , l\'orso bruno animale pericoloso , causa grande mole forza fisica può diventarlo rare particolari condizioni : quando ferito ; tratta femmina cuccioli ; viene sorpreso carcassa altre fonti cibo ; viene disturbato tana pressi ; presente cane ( va assolutamente tenuto guinzaglio ) ; viene sorpreso all\'improvviso spaventato . Quest\'ultimo caso verosimilmente meglio allinea potrebbe essere accaduto sfortunato giovane Trentino . genere orsi paura dell\'uomo allontano , possono mettere atto comportamenti difensivi / aggressivi quando sentono minacciati , via fuga . comportamento tenere quando avvista orso allontanarsi dall\'animale lentamente , parlando voce alta calma , senza voltare spalle soprattutto senza darsi fuga ( un\'azione potrebbe renderci preda occhi plantigrado ) . sempre importante farsi sentire ambienti vivono orsi andarci solo potenzialmente pericoloso andare compagnia . Quando chiaro l\'orso attaccarci , dobbiamo farci prendere panico provare combattere l\'animale . alcuna speranza causa forza dell\'agilità . provare scalare albero servirebbe nulla , dato animali abilissimi farlo . raccomandazione esperti sdraiarsi terra giù mani ( zaino ) nuca , senza gridare provare fuggire , terrificanti possano essere quei momenti . L\'orso , infatti , dopo aver dato eventuali colpi avvertimento potrebbe allontanarsi , appurato minaccia . comportamento viene ben insegnato Slovenia ( orsi numerosi ) sin tenera età . LAV ricorda quando avventuriamo sentiero , entrando territorio fauna selvatica va fatto massimo rispetto , `` consapevolezza comportamenti determinare reazioni qualsiasi animale selvatico \'\' . frequenta ambienti vivono orsi dovrebbe essere sempre ben informato comportamenti tenere , l\'approccio personale animali può fare davvero differenza vita morte caso incontro . Tuttavia , naturalmente , convivenza orsi persone può essere delegata solo modus operandi singoli . territori condivisi vanno gestiti affinché riducano probabilità incontro possibili ...
#     }
#   }
#   fields {
#     key: "authors"
#     value {
#       string_value: "Andrea Centini"
#     }
#   }
#   fields {
#     key: "alexaGlobalRank"
#     value {
#       string_value: "10261"
#     }
#   }
#   fields {
#     key: "War__Conflict"
#     value {
#       number_value: 0.00047664443263784051
#     }
#   }
#   fields {
#     key: "WORK_OF_ART_mean_salience"
#     value {
#       number_value: 0.000591626507230103
#     }
#   }
#   fields {
#     key: "Violent"
#     value {
#       number_value: 0.23780487477779388
#     }
#   }
#   fields {
#     key: "Toxic"
#     value {
#       number_value: 0.10497836023569107
#     }
#   }
#   fields {
#     key: "Sexual"
#     value {
#       number_value: 0.0024352301843464375
#     }
#   }
#   fields {
#     key: "Religion__Belief"
#     value {
#       number_value: 0.006455778144299984
#     }
#   }
#   fields {
#     key: "Public_Safety"
#     value {
#       number_value: 0.41085270047187805
#     }
#   }
#   fields {
#     key: "Profanity"
#     value {
#       number_value: 0.023985227569937706
#     }
#   }
#   fields {
#     key: "Politics"
#     value {
#       number_value: 0.011267605237662792
#     }
#   }
#   fields {
#     key: "PRICE_mean_salience"
#     value {
#       number_value: 0
#     }
#   }
#   fields {
#     key: "PERSON_mean_salience"
#     value {
#       number_value: 0.0014973216926709057
#     }
#   }
#   fields {
#     key: "OTHER_mean_salience"
#     value {
#       number_value: 0.0033867501069356591
#     }
#   }
#   fields {
#     key: "ORGANIZATION_mean_salience"
#     value {
#       number_value: 0.0014577196173680325
#     }
#   }
#   fields {
#     key: "Legal"
#     value {
#       number_value: 0.10094637423753738
#     }
#   }
#   fields {
#     key: "LOCATION_mean_salience"
#     value {
#       number_value: 0.0043089465491056187
#     }
#   }
#   fields {
#     key: "Insult"
#     value {
#       number_value: 0.11448121070861816
#     }
#   }
#   fields {
#     key: "Illicit_Drugs"
#     value {
#       number_value: 0.0095541402697563171
#     }
#   }
#   fields {
#     key: "Health"
#     value {
#       number_value: 0.050200805068016052
#     }
#   }
#   fields {
#     key: "Firearms__Weapons"
#     value {
#       number_value: 0.10526315867900848
#     }
#   }
#   fields {
#     key: "Finance"
#     value {
#       number_value: 0.0076335878111422062
#     }
#   }
#   fields {
#     key: "EVENT_mean_salience"
#     value {
#       number_value: 0.0024181962362490594
#     }
#   }
#   fields {
#     key: "Derogatory"
#     value {
#       number_value: 0.018460642546415329
#     }
#   }
#   fields {
#     key: "Death_Harm__Tragedy"
#     value {
#       number_value: 0.94152045249938965
#     }
#   }
#   fields {
#     key: "CONSUMER_GOOD_mean_salience"
#     value {
#       number_value: 0.000889976869802922
#     }
#   }
# }
# ]
# ENDPOINTS:
#  automl_datasetnlp_20240325224945
# PREDICTIONS
#
# +------------------------+------------+
# | Class                  |      Score |
# +========================+============+
# | Technology             | 0.00651041 |
# +------------------------+------------+
# | Sports                 | 0.928073   |
# +------------------------+------------+
# | Science                | 0.00101889 |
# +------------------------+------------+
# | Politics               | 0.0162563  |
# +------------------------+------------+
# | Health                 | 0.00204835 |
# +------------------------+------------+
# | Environment            | 0.00269876 |
# +------------------------+------------+
# | Business               | 0.0195512  |
# +------------------------+------------+
# | Arts and Entertainment | 0.0238427  |
# +------------------------+------------+
